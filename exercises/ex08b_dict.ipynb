# %% [markdown]
# ### Creating and Accessing Dictionaries

# %% [markdown]
# #### 1
# Create a dictionary that maps the first 5 positive integers to their squares.
# Example: {1: 1, 2: 4, ...}

# %% [markdown]
# #### 2
# Create a dictionary that stores the names and ages of five people.
# Print the entire dictionary
# Print arben ages
# Print its length.

# %% [markdown]
# #### 3
# Given the dictionary below, update the age of 'Arben' to 30, and add a new entry for 'Yin' with age 25.
#
# people = {'Arben': 28, 'Ilia': 22}

# %% [markdown]
# #### 4
# Using zip(), build a dictionary that maps countries to their capitals.

# %% [markdown]
# #### 5
# Use a dictionary to simulate a phonebook (name â†’ phone number). Then:
#
# 1.  add a new contact
# 1.  update an existing contact
# 1.  delete a contact

# %% [markdown]
# #### 6
# Given a dictionary of student names and their marks, write code to:
#
# 1.  print the highest score
# 1.  print the name of the student with the lowest score

# %% [markdown]
# #### 7
# ##### Frequency Counter
# Write a program that counts the frequency of each character in a string and stores the result in a dictionary.

# %% [markdown]
# ### Dictionary Comprehension

# %% [markdown]
# #### 8
# Write a dictionary comprehension that maps numbers from 1 to 10 to either 'even' or 'odd'.

# %% [markdown]
# #### 9
# Given this list of words:
# words = ['python', 'dictionary', 'exercise', 'comprehension', 'practice']
#
# Create a dictionary where keys are the words and values are the length of each word using dictionary comprehension

# %% [markdown]
# #### 10
# Given a dictionary of items and their prices, increase each price by 10%.
# *Hint: You may use the `round(value, precision)` function to make the results more pleasing*

# %% [markdown]
# #### 11
# ##### Merge Two Dictionary
# Write code to merge two dictionaries into one. If a key exists in both, add their values.

# %% [markdown]
# #### 12
# Create a nested dictionary to represent three students, each with a name, age, and grade.

# %% [markdown]
# #### 13
# Create a dictionary where the keys are words in a sentence and the values are the number of times each word appears.

# %% [markdown]
# #### 14
# ##### Grouping by First Letter
# Given a list of names, build a dictionary that groups names by their first letter.
# Example:
#
# ['Alice', 'Arben', 'Bob', 'Bella']
# results -> {'A': ['Alice', 'Arben'], 'B': ['Bob', 'Bella']}

# %% [markdown]
# #### 15
# ##### Reverse a Dictionary
# Write code that inverts a dictionary (swap keys and values).
# Example:
#
# {'ilia': 54, 'hao': 64}
# result -> {54: 'ilia', 64: 'hao'}

# %% [markdown]
# #### 16
# Student Averages
# You are given a dictionary where keys are student names and values are lists of scores.
# Example:
#
# {'ilia': [50, 60, 70], 'hao': [80, 90, 100]}

# %% [markdown]
# #### 17
# ##### Histogram from a List
# Given a list of integers, build a dictionary where each key is a number and its value is the count of how many times it appears.
#
# numbers = [1, 2, 4, 2, 1, 2, 3, 3, 3, 4]
# Expected Output: {1: 2, 2: 3, 4: 2, 3: 3}

# %% [markdown]
# ####
