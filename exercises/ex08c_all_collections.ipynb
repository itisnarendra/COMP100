# %% [markdown]
# ## For loops with str

# %% [markdown]
# #### 1
# Write function that takes a string and prints each letter separated by a single space.
# Create a string variable and then invoke the function
#
# ##### Sample output
# for argument **Python**:
#
# ```
# P y t h o n
# ```

# %% [markdown]
# #### 2
# Create a function that take a string and print letter preceded by its index
#
# ##### Sample
# for argument **Hello**:
#
# ```
# 0 H
# 1 e
# 2 l
# 3 l
# 4 o
# ```
#
# ---

# %% [markdown]
# #### 3
# Write a function that takes a numeric string and that returns the sum of the digits.
# Prompt the user for a number. Invoke the function and with the input and print the result.
#
# ##### Sample output:
# ```
# Sum of the digits of 456701 is 23
# ```
#
# **Hint:** process the user input as a string
# **Question:** Can your program work with any size of integer?

# %% [markdown]
# ### 4
# Write a function that takes a numeric string and that returns a count of the number of upper-cased letters present.
# Prompt the user for a string. Invoke the function and with the input and print the result.
#
# ##### Sample output:
# ```
# There are 5 uppercased letters in "Mary Had A Little Lamb."
# ```
#
# *Hint: To check the case of a character use the `isupper()` method of the str class*
#
# ---

# %% [markdown]
# ## For loops with lists

# %% [markdown]
# ### 5
# Write a function that takes a list of numbers and return the sum of the items.
# Declare and initialize a suitable variable. Invoke the function and print the result
#
# ##### Sample output:
# ```
# The sum of the items in [3, 10, -4, 7, 8] is 24
# ```
#
# Use a `for` loop (do not use `sum()`).

# %% [markdown]
# ### 6
# Write a function that takes a list of numbers and return a count of the positive items (*i.e. greater than 0*).
# Declare and initialize a suitable variable. Invoke the function and print the result
#
# ##### Sample output:
# ```
# There are 5 positive numbers in [5, 12, 0, 7, -5, 9, -1, 3]
# ```

# %% [markdown]
# #### 7
# Write a function that takes a list of numbers and returns the smallest item.
# Declare and initialize a suitable variable. Invoke the function and print the result
#
# ##### Sample output:
# ```
# The smallest number in [5, 2, 11, 6, 20, 7, 14] is 2
# ```
#
#
# *Hint you must not use the `min()` function*

# %% [markdown]
# #### 8
# Write a function that takes a list of items and prints each item preceeded by its index.
# Declare and initialize a suitable variable and invoke the function.
#
# ##### Sample output:
# ```
# 0 : 80
# 1 : 92
# 2 : 77
# ```

# %% [markdown]
# #### 9
# Write a function that takes a list of numbers and returns a new list containing their squares.
# Declare a initialize a suitable variable. Invoke the function and and print the results.
#
# ##### Sample output:
# ```
# original: [1, 2, 3, 4]
#  squares: [1, 4, 9, 16]
# ```

# %% [markdown]
# #### 10
# Write a function that takes a list of string and prints each items on one line separated by a single space.
# Declare a initialize a suitable variable and invoke the function.
#
# ##### Sample output:
# for argument ['Python', 'is', 'fun', 100, '%.']
# ```
# Python is fun 100 !.
# ```

# %% [markdown]
# #### 11
#
# Write a function that takes a list of numbers and prints the square of each items on the same line seperated by a single space.
# Declare a initialize a suitable variable and invoke the function.
#
# ##### Sample output:
# for argument [5, 2, 11, 6, 20, 7, 14]
# ```
# 25 4 121 36 400 49 196
# ```

# %% [markdown]
# #### 12
# Write a function that takes a list of numbers and collects only the even items in a new list and returns this list.
# Declare a initialize a suitable variable. Invoke the function and print the resulting value.
#
# ##### Sample output:
# ```
# The even numbers in [5, 2, 11, 6, 20, 7, 14] are [2, 6, 20, 14]
# ```

# %% [markdown]
# #### 13
# Write a function that takes a list of strings and a string. The function will retrun True or False depending if the second argument is present in the list.
# Declare a initialize a list suitable variable and a string value. Invoke the function and print a meaningful message depending on the result.
#
# ##### Sample of two runs:
# ```
# The word "was" was found in ['Mary', 'had', 'a', 'little', 'lamb,', 'its', 'fleece', 'was', 'white', 'as', 'snow.'].
# The word "were" was NOT found in ['Mary', 'had', 'a', 'little', 'lamb,', 'its', 'fleece', 'was', 'white', 'as', 'snow.'].
# ```
#
#
# *(No `in` allowed.)*

# %% [markdown]
# #### 14
# Write a function that takes two lists. The function returns a new list with the sum of the corresponding items.
#
# Declare and initialize two apropriate variables. Invoke the function and print the resulting value
#
# ##### Sample output:
# ```
# [1, 2, 3] + [10, 20, 30] = [11, 22, 33]
# ```
#
# (No list comprehension.)

# %% [markdown]
# ## for loops with tuples

# %% [markdown]
# #### 15
# Write a function that takes a tuple and prints all the items on separate lines.
# Declare a initialize a suitable variable and invoke the function
#
# ##### Sample output:
# ```
# red
# green
# blue
# yellow
# ```

# %% [markdown]
# #### 16
# Write a function that takes a tuple of numbers and returns the sum of all the items.
# Declare a initialize a suitable variable and invoke the function
#
# ##### Sample output:
# ```
# The sum of the items in (3, 5, 7, 9, 12, 10) is 46
# ```

# %% [markdown]
# #### 17
# Write a function that takes a tuple of numbers and prints the items preceded by their indices.
# Declare a initialize a suitable variable and invoke the function
#
# ##### Sample output:
# ```
# 0 10
# 1 20
# 2 30
# ```

# %% [markdown]
# #### 18
# Write a function that takes a tuple of tuple of pairs of numbers and unpacks and prints each pair.
# Declare a initialize a suitable variable and invoke the function
#
# ##### Sample output:
# for argument ((1, 2), (3, 4), (5, 6))
# ```
# x = 1 y = 2
# x = 3 y = 4
# x = 5 y = 6
# ```

# %% [markdown]
# #### 19
# Write a function that takes a tuple of numbers and a number and return the number of item greater than the second argument.
# Declare a initialize two suitable variables. Invoke the function and print the resulting value.
#
# ##### Sample output:
# ```
# There are 3 values greater than 10 in (5, 12, 7, 18, 2, 30)
# ```

# %% [markdown]
# ## For loop with set

# %% [markdown]
# #### 20
# Write a function that takes a set of items and prints each items by a space on one line.
# Declare a initialize a suitable variable and invoke the function.
#
# ##### Sample output:
# with argument {'Mary', 'had', 'a', 'little', 'lamb'}
# ```
# had little lamb a Mary
# ```
# *Can you explain why the order is different?*

# %% [markdown]
# #### 21
# Write a function that takes a set of items and prints each items preceded by an index an separate lines.
# Declare a initialize a suitable variable and invoke the function.
#
# ##### Sample output:
# with argument {'Mary', 'had', 'a', 'little', 'lamb'}
# ```
# 0 had
# 1 little
# 2 lamb
# 3 a
# 4 Mary
# ```
# **Hint**: You have to use the `enumerate()` function

# %% [markdown]
# ## For loop with dict

# %% [markdown]
# #### 22
# Write a function that take a dict as argument and prints all the keys on a single line seperated by a space.
# Declare a suitable variable. Invoke the function with the variable.
#
# ##### Sample output:
# with argument {'name': 'Alice', 'age': 30, 'city': 'New York'}
# ```
# name age city
# ```

# %% [markdown]
# #### 23
# Write a function that take a dict as argument and prints all the keys on seperate lines.
# Declare a suitable variable. Invoke the function with the variable.
#
# ##### Sample output:
# with argument {'name': 'Alice', 'age': 30, 'city': 'New York'}
# ```
# name
# age
# city
# ```

# %% [markdown]
# #### 24
# Write a function that take a dict as argument and prints all the values on seperate lines.
# Declare a suitable variable. Invoke the function with the variable.
#
# **Hint:** Use the `values()` method of the dict class to access the values
#
# ##### Sample output:
# with argument {'name': 'Alice', 'age': 25, 'city': 'Toronto'}
# ```
# Alice
# 25
# Toronto
# ```

# %% [markdown]
# #### 25
# Write a function that take a dict as argument and prints all the key-value on seperate lines.
# Declare a suitable variable. Invoke the function with the variable.
#
#
# ##### Sample output:
# with argument {'name': 'Alice', 'age': 30, 'city': 'Toronto'}
# ```
# name : Alice
# age : 25
# city : Toronto
# ```

# %% [markdown]
# #### 26
# Write a function that take a dict as argument. The function sorts the key and then prints all the key-value pairs on seperate lines.
# Declare a suitable variable and then invoke the function.
#
# ##### Sample output:
# with argument {'name': 'Alice', 'age': 25, 'city': 'Toronto'}
# ```
# age -> 25
# city -> Toronto
# name -> Alice
# ```

# %% [markdown]
# #### 27
# Write a function that take a dict as argument. The function returns the number of student with passing grade (a grade over 50%).
# Declare a suitable variable. Invoke the function and print the resulting value.
#
# ##### Sample output:
# with argument { 'Amy': 85, 'James': 42, 'Hina': 77, 'Leo': 55 }
# ```
# There are 3 students with a passing grade.
# ```

# %% [markdown]
# #### 28
# Write a function that take a dict as argument. The function returns a list of keys.
# Declare a suitable variable. Invoke the function and print the resulting value.
#
# ##### Sample output:
# with argument {'name': 'Alice', 'age': 30, 'city': 'New York'}
# ```
# ['name', 'age', 'city']
# ```

# %% [markdown]
# #### 29
# Write a function that take a dict as argument. The function returns the sum of the values.
# Declare a suitable variable. Invoke the function and print the resulting value.
#
#
# ##### Sample output:
# with argument { 'apple': 10, 'banana': 6, 'mango': 3}
# ```
# The total number of items in the inventory is 19
# ```

# %% [markdown]
# #### 30
# Write a function that take a dict as argument. The function returns a list of string of the key-value pairs.
# Declare a suitable variable. Invoke the function and print the resulting value.
#
# ##### Sample output:
# with argument {'name': 'Alice', 'age': 25, 'city': 'Toronto'}
# ```
# ['name: Alice', 'age: 25', 'city: Toronto']
# ```

# %% [markdown]
# #### 31
# Write a function that take a dict as argument. The function returns the key that referencee the largest value.
# Declare a suitable variable. Invoke the function and print the resulting value
#
# ##### Sample output:
# with argument { 'Jan': 1200, 'Feb': 900, 'Mar': 1500}
# ```
# Key with the largest value is Mar
# ```

# %% [markdown]
# #### 32
# Write a function that take a list as argument. The function returns a dict where the key is the number of letters in an items in the argument and the value is a list of items with the correspending sizes.
# Declare a suitable variable. Invoke the function and print the resulting value
#
# ##### Sample output:
# with argument  ['hi', 'cat', 'dog', 'apple', 'sun']
# ```
# {2: ['hi'], 3: ['cat', 'dog', 'sun'], 5: ['apple']}
# ```

# %% [markdown]
# #### 33
# Write a function that take a list of strings as argument. The function returns a dict where the key is the number of letters in the argument and the value is the number of occurences of that letter.
#
# Ask the user for a string. Invoke the function and print the resulting value
# Make a dictionary where each letter is a key and the count is the value.
#
# **Hint:** You may ignore spaces.
#
# ##### Sample output:
# with argument 'Narendra is evil!'
# ```
# {'N': 1, 'a': 2, 'r': 2, 'e': 2, 'n': 1, 'd': 1, 'i': 2, 's': 1, 'v': 1, 'l': 1, '!': 1}
# ```

# %% [markdown]
# ### For loop with combinations (str, list, tuples and dict)

# %% [markdown]
# ### 34
# Write a function that take a list of strings as argument. The function returns the longest word in the list.
#
# Ask the user for a string. Invoke the function and print the resulting value
#
# ##### Sample output:
# with argument 'Narendra is the most evil instructor at Centennial'
# ```
# The longest word is "instructor"
# ```
