# %% [markdown]
# ## None
# ### Exercise 1
# Create a variable with the value None and compare it to 0, False, '', and None.
#
# Print the results of each of the comparisons using f-strings.
#
# Explain why only one of them is True.
#
# *Hint: Use f-strings to display more meaningful output*

# %% [markdown]
# ## Checking Data Types
#
# ### Exercise 2:
# Using the type() function print the type of each of the following literals:
# -   32
# -   3.141592
# -   True
# -   'Narendra is evil!'
# -   {1, 3, 2, 3, 4}
# -   (4, 'five', 6.0, {'one})
# -   [1, '1.1', 1.2, (2,)]
# -   {0: 'zero', 1: 'one', 2: 'two'}

# %% [markdown]
# ## Strings
#
# ### Exercise 3:
#
# Ask the user for their first, middle name and last name.
#
# Print the name in three different formats:
# -   [first name] [last name]
# -   [first name] [middile name] [last name]
# -   [last name], [first name] [middle name]
#
# You must only prompt the user once for his first, middle and last names
#
# *Hint: Use f-strings to simplify your coding*
#
# #### Example
# For inputs of Barack, Hosein and Obama for the three names, your three outputs should be:
# -   Barack Obama
# -   Barack Hosein Obama
# -   Obama, Barack Hosein

# %% [markdown]
# ## Tuples
#
# ### Exercise 4:
#
# Create a tuple with at least 5 elements (mix of int, str, float).
#
# Print the tuple
#
# *Hint: Assign the tuple literal to a variable and then print that variable*

# %% [markdown]
# ## Lists
#
# ### Exercise 5:
#
# Create a list with at least 5 elements (mix of int, str, float).
#
# Print the list
#
# *Hint: Again, assign the list literal to a variable and then print that variable*

# %% [markdown]
# ## Sets
#
# ### Exercise 6:
#
# Create a set with at least 10 elements (mix of int, str, float). Ensure that you have some duplicates.
#
# Print the set and note what happend to the duplicates

# %% [markdown]
# ## Dictionaries
#
# ### Exercise 7:
#
# Create a dictionary with keys: 'name', 'age', 'course'. You get to choose the values for each key.
#
# Print the entire dictionary.

# %% [markdown]
# ## Boolean
#
# ### Exercise 8:
# Write a program that prints the truth value of the following expressions:
#
# -   bool(None)
# -   bool('')
# -   bool([])
# -   bool(0)
# -   bool(42)
# -   bool('Python')

# %% [markdown]
# ## Integers
#
# ### Exercise 9:
# Write the statement that:
#
# Stores the following integer literals in variables:
#
# -   Decimal: 42
# -   Binary: 0b101010
# -   Octal: 0o52
# -   Hexadecimal: 0x2A
#
# Print each variable and confirm all are equal using ==.

# %% [markdown]
# ## Floats
#
# ### Exercise 10:
#
# Ask the user for a circleâ€™s radius.
#
# Calculate and print the area using Ï€ = 3.1415.
#
# Displaying your result with 2 decimal places.

# %% [markdown]
# ### Exercise 11:
# Write the statements that prompts the user for the number of siblings his has. Your code should display the message, 'I also have 4 siblings' (assuming that the user enters 4).

# %% [markdown]
# ### Exercise 12:
# Write the statements that prompts the user for two integer. You must display the results of summing and finding the difference.
#
# #### Example
# If the user enters 8 and 3 at the prompts, then the following should be displayed:
# -   8 + 3 = 11
# -   8 â€“ 3 = 5

# %% [markdown]
# ### Exercise 13:
# Write the statements that prompts the user for a number (that may have a fractional part). If should then display the original number, the integer and the letter equivalent.
# This exercise requires you to convert the original float to an int, and the original float to a letter
#
# #### Example
# If the user enters 65.790, then the following should be displayed:
# -   Original number -> 65.790
# -   Converted to int -> 65
# -   Converted to letter-> A
#
# Hint:
# -   store the original number as a float
# -   use the int() to convert the above to int
# -   use chr() to convert the above int to letter
# -   then use the print() three times to get the output
# -   to get the three decimal for the original number you must use `:.3f` after the float variable

# %% [markdown]
# ### Exercise 14:
# Write the statements to calculate and display the potential difference between the ends of a wire. You must prompt the user for the current flowing and the resistance of the wire.
#
# #### Example
# If the user enters 1.5 for the current and 6 for the resistance, then the following should be displayed:
# If the current is 1.50A and the resistance is 6.00Î© , then the potential difference will be 9.00V
#
# Hint:
# -   Potential difference is the product of the current and the resistance and either value may have a fractional part
# -   do the calculation and then do a single print statement to produce the output
# -   to get the two decimal, you must use `:.2f` after all three float variables

# %% [markdown]
# ### Exercise 15:
# Adult tickets cost $3.75 and child tickets cost $2.25. Write the statements to calculate and display the potential difference between the ends of a wire. You must prompt the user for the current flowing and the resistance of the wire.
#
# #### Example
# If the user enters 4 and 8 for adults and children respectively, then the following should be displayed:
# 4 adults and 8 children will cost $33.00
#
# Hint:
# -   to print currency, use a $ symbol and display two decimal places
