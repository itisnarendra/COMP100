# %% [markdown]
# ### Creating Sets

# %% [markdown]
# #### 1
# Create an empty list and confirm its type and the number of items in it

# %% [markdown]
# #### 2
# Make a set from the string 'Mississippi'.
#
# Print the resulting set and a count of them.

# %% [markdown]
# #### 3
# Prompt the user for a word and then print the number of unique vowels in it.

# %% [markdown]
# ### Common Operations
# Given the two sets

# %% [markdown]
# #### 4
# Find the union of a and b

# %% [markdown]
# #### 5
# Find the intersection of a and b

# %% [markdown]
# #### 6
# Find which elements are in a but not in b

# %% [markdown]
# ### Set Methods
#
# #### 7
# Start with the set `{1, 3, 5}`
#
# Write the statement to do the following:
#
# 1.  Add the number 9
# 1.  Remove the number 3
# 1.  Update the set with [9, 11]
# 1.  Print the resulting set

# %% [markdown]
# #### 8
# Write the statement to remove the duplicates for a list using a set.
#
# nums = [4, 5, 6, 4, 5, 7, 8, 9, 7, 6]

# %% [markdown]
# #### 9
# Create two sets of letters from the words "python" and "typhoon".
#
# 1.  Find letters they have in common.
# 1.  Find letters unique to "python".
# 1.  Find letters unique to "typhoon".
# 1.  Find all unique letters from both words. *[Use the results of the previous two steps]*
