# %% [markdown]
# ## Variables

# %% [markdown]
# ### Naming Rules

# %% [markdown]
# ### Using Built-in Functions

# %% [markdown]
# #### type() function

# %% [markdown]
# #### id() function

# %% [markdown]
# #### dir() function

# %% [markdown]
# #### input() function

# %% [markdown]
# #### eval()

# %% [markdown]
# #### Challenge
