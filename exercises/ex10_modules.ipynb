# %% [markdown]
# #### 1 - Creating Your Own Module
#
# Create a new file named `mymath.py`.
# Inside it, define the following functions:
#
# ```python
# def add(a, b):
#     return a + b
#
# def subtract(a, b):
#     return a - b
#
# def multiply(a, b):
#     return a * b
# ```
#
# Save the file in the same directory as this notebook.
# In a cell below,  import your module and test it:
#
# ##### Sample output
# ```text
# mymath.add(10, 5) = 15
# mymath.subtract(10, 5) = 5
# mymath.multiply(10, 5) = 50
# ```

# %% [markdown]
# #### 2 - Importing Specific Items
#
# Write the code to import only one function and use it
#
# Now try using a function that wasnâ€™t imported.
# What happens? Why?
#
# ##### Sample output
# ```text
# add(7, 3) = 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 from mymath import add
#       3 print(f'{add(7, 3) = }')
# ----> 4 print(f'{subtract(7, 3) = }')
#
# NameError: name 'subtract' is not defined
# ```

# %% [markdown]
# #### Exercise 3 - Using an Alias
#
# Import your module with an alias (say `mm`) and call its functions:
#
# ##### Sample output
#
# ```text
# mm.add(7, 3) = 10
# ```
#
# Why might using aliases be useful in large projects?

# %% [markdown]
# #### 4 - Exploring Built-in Modules
#
# Use the built-in math module:
#
# ##### Sample output
#
# ```text
# math.sqrt(16) = 4.0
# math.pi = 3.141592653589793
# dir(math) =['__doc__', '__loader__', '__name__',  ... ]
# ```
#
# What does `dir(math)` show?
# Which other useful functions can you find?

# %% [markdown]
# #### 5 - Packages in Action
#
# Create a folder named `mypackage` with the following structure:
# ```text
# mypackage/
#     __init__.py
#     greetings.py
# ```
# Leave `__init__.py` empty
#
# In greetings.py, add:
# ```python
# def say_hello(name):
#     return f'Hello, {name}!'
# ```
#
# Write the statement to use the `say_hello()` function in the `greetings` module of the `mypackage` package
# ##### Sample output
# ```text
# say_hello("Alice") = 'Hello, Alice!'
# ```

# %% [markdown]
# #### 6 - Using the __name__ Variable
#
# Add the following to your `mymath.py` file:
# ```python
# if __name__ == '__main__':
#     print('mymath module is running directly!')
# ```
#
# Then run `mymath.py` directly, and afterwards import it from `main.py`.
# Observe the difference in output â€” whatâ€™s happening?

# %% [markdown]
# #### 7 - Installing and Using Third-Party Modules
#
# Use pip to install the `requests` module:
# ```python
# pip install requests
# ```
#
# Then, in Python:
# ```python
# import requests
# response = requests.get('https://api.github.com')
# print(response.status_code)
# ```
#
# What does the program output, and what does it mean?

# %% [markdown]
# #### Challenge Exercise â€” Module Reloading
#
# In an interactive Python session (or Jupyter notebook):
#
# Import your `mymath` module and use one of its functions.
#
# Modify the module file (e.g., change a print statement or function behavior).
#
# Reload it using:
# ```python
# import importlib
# importlib.reload(mymath)
# ```
#
# Test again and confirm that the changes are reflected without restarting Python.
