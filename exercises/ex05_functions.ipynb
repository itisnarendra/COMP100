# %% [markdown]
# ### Part A: Basics of Functions

# %% [markdown]
# #### 1 - Defining & Calling Functions
#
# Write a function called say_hello() that prints "Hello World".
#
# Call the function three times

# %% [markdown]
# #### 2 - Function with No Return
#
# Write a function print_name() that takes one parameter name and prints "Hello, <name>".
#
# Try calling it with your name.

# %% [markdown]
# #### 3 - Function with Return
#
# Write a function square(n) that returns the square of n.
#
# Call it with values 2, 5, and 10 and print the results like:
#
# The square of 2 is 4
#
# The square of 3 is 9
#
# The square of 5 is 25

# %% [markdown]
# ### Part B: Parameters & Return Values

# %% [markdown]
# #### 4 - Max of Two Numbers
#
# Write a function max_of_two(x, y) that returns the larger of the two numbers.
#
# Do not use Pythonâ€™s built-in max().
#
#
# Call this function three times and display the results in a meaningful way
# e.g.
# The maximum of 10 and 20 is 20
# The maximum of 30 and 20 is 30

# %% [markdown]
# #### 5 - Even or Odd
#
# Write a function is_even(n) that returns True if n is even, otherwise False.
#
# Test with numbers 3, 10, and 15.
#
# Display your result like:
#
# Is 3 even? -> False
#
# Is 10 even? -> True
#
# Is 15 even? -> Fals

# %% [markdown]
# #### 6 - Two Parameters
#
# Define a function add(x, y) that returns the sum of two numbers.
#
# Call it with different values.
#
# Show your results like:
#
# -3 + -1 = -4
#
# 3.5 + -1 = 2.5
#
# 3.5 + 2.5 = 6.0

# %% [markdown]
# #### 7 - Word Count
#
# Write a function count_words(sentence) that returns the number of words in a given string.

# %% [markdown]
# #### 8 - Initials Generator
#
# Write a function get_initials(first, last) that returns a string of initials.
#
# Example: get_initials("Alice", "Johnson") -> "A.J."
#
# Your output should look like:
#
# The initials of "John Doe" are J.D.
#
# The initials of "Alice Bob Carol" are A.B.C.

# %% [markdown]
# #### 9 - Vowel Counter
#
# Write a function count_vowels(sentence) that counts and returns the number of vowels in the argument.
#
# Hint:
# -   create an accumulator that will keep the count
# -   create a variable that contains all the vowels (of both cases)
# -   using a looping construct, check if a letter of the argument is in the above variable and update the count accordingly

# %% [markdown]
# #### 10 - Find Minimum
#
# Write a function find_min(numbers) that returns the smallest number from a list.
#
# Your output should look like:
#
# The minimum of [3, 1, 4, 1, 5, 9, 2, 6, 5] is 1
#
# The minimum of [-10, -20, 0, 10, 20] is -20

# %% [markdown]
# #### 11 - List Average
#
# Write a function average(numbers) that calculates and returns the average of numbers in a list.
#
# YOu may not used the built-in sum() function.
#
# Your output should look like:
#
# The average of [1, 2, 3] is 2.0
#
# The average of [10, 20, 30, 40, 50] is 30.0
#
# The average of [5, 15, 25, 35, 45, 55] is 30.0

# %% [markdown]
# #### 12 - Square List
#
# Write a function square_list(numbers) that returns a new list where each number is squared.
#
# Your output should look like:
#
# The squares of [1, 2, 3, 4, 5] are [1, 4, 9, 16, 25]
#
# The squares of [6, -7, 1.2] are [36, 49, 1.44]

# %% [markdown]
# #### 13 - Default Parameters
#
# Create a function greet(name, greeting="Hi") that prints a message.
#
# Call it once with one argument, and once with both arguments.

# %% [markdown]
# #### 14 - Ticket Price Calculator
#
# Write a function ticket_price(age, discount=0.1) that calculates ticket price.
#
# Base price = $20. Apply discount only if discount is given.

# %% [markdown]
# #### 15 - Voting illegibility
# Write a function can_vote(age, is_resident = True) that return True if age is more than 18 and the person is a resident.
#
# Try to match the following output:
#
# Single parameter
#
# Age: 17 can vote? -> False
#
# Age: 20 can vote? -> True
#
# Two parameters
#
# Age: 20 residency: False? -> False
#
# Age: 20 residency: True? -> True
#
# Age: 15 residency: True? -> False

# %% [markdown]
# #### 16 - Greeting with Language Option
#
# Write a function greet(name, language="en") that prints a greeting.
#
# If language is "en" -> "Hello <name>"
#
# If "es" -> "Hola <name>"
#
# If "fr" -> "Bonjour <name>".

# %% [markdown]
# #### 17 - Named Parameters
#
# Write a function calculate_cost(price, tax=0.13) that returns the total price after tax.
#
# Call it using positional arguments, keyword arguments, and with both values.

# %% [markdown]
# ### Part C: Variable Scope

# %% [markdown]
# #### 18 - Global vs Local
#
# Create a global variable count = 10.
#
# Write a function increase() that and prints it and then increase it.
#
# Invoke the function increase()
#
# Print the global variable after calling increase().
#
# Use the global keyword to modify the global variable inside the function.

# %% [markdown]
# ### Part D: Variable-Length Arguments

# %% [markdown]
# #### 19 - Using *args
#
# Write a function multiply_all(*numbers) that multiplies any number of arguments together.
#
# Test it with multiply_all(1, 2) and multiply_all(2, 3, 4).
#
# Sample output:
#
# multiply_all(1, 2) - > 2
#
# multiply_all(2, 3, 4) - > 24

# %% [markdown]
# #### 20 - Find Maximum with *args
#
# Write a function find_max(*numbers) that returns the largest number from the arguments given.

# %% [markdown]
# #### Shopping List with **kwargs
#
# Write a function print_shopping_list(**items) that prints each item and its price.
#
# Example call:
#
# print_shopping_list(apple=2.5, bread=3.0, milk=4.0)

# %% [markdown]
# #### Using **kwargs
#
# Write a function print_student_info(**info) that prints all key-value pairs given as arguments.
#
# Example call: print_student_info(name="Alice", age=20, program="Computer Science").

# %% [markdown]
# ### Part E: Type Hints & Annotations

# %% [markdown]
# #### 21 - Type Annotations
#
# Write a function area_of_triangle(base: float, height: float) -> float that returns the area of a triangle.
#
# Call it with different values and print results.

# %% [markdown]
# #### 22 - BMI Calculator
#
# Write a function bmi(weight: float, height: float) -> float that calculates body mass index:
#
# BMI = weight/(height * height)

# %% [markdown]
# #### 23 - Distance Formula
#
# Write a function distance(x1: float, y1: float, x2: float, y2: float) -> float that returns the distance between two points.

# %% [markdown]
# ### Part F: Recursion

# %% [markdown]
# #### 24 - Factorial Function
#
# Write a recursive function factorial(n: int) -> int that computes factorial.
#
# Test with factorial(5) and factorial(0).
# Sample output:
#
# 0 factorial is 1
#
# 5 factorial is 120

# %% [markdown]
# #### 25 - Sum of Natural Numbers
#
# Write a recursive function sum_n(n) that returns the sum of numbers from 1 to n.
#
# Your output should look like:
#
# The sum of first 3 natural numbers is 6
#
# The sum of first 5 natural numbers is 15
#
# The sum of first 10 natural numbers is 55

# %% [markdown]
# #### 26 - Power Function
#
# Write a recursive function power(base, exp) that computes  base ^ exp
#
# Sample output:
#
# 2 raised to the power 3 is 8
#
# 5 raised to the power 4 is 625
#
# 10 raised to the power 0 is 1

# %% [markdown]
# #### 27 - String Reversal
#
# Write a recursive function reverse_string(s: str) -> str that returns the reversed string.
#
# Test with "hello" and "world".
#
# Sample output:
#
# The reverse of "Hello" is "olleH"
#
# The reverse of "world" is "dlrow"

# %% [markdown]
# ### Part G: Lambda Expressions

# %% [markdown]
# #### 28 - Square with Lambda
#
# Write a normal function square(x) and then write a lambda function that does the same.
#
# Compare results with inputs 3 and 7.

# %% [markdown]
# #### 29 - Lambda with Multiple Parameters
#
# Use a lambda to create a function add = lambda x, y: x + y.
#
# Test with add(4, 6) and add(-2, 10).

# %% [markdown]
# ### Part H: Challenge Problems

# %% [markdown]
# #### 30 - Fibonacci (Recursion)
#
# Write a function fibonacci(n: int) -> int that returns the nth Fibonacci number. You may ignore negative arguments/
#
# Test with values 5, 10, and 15.
#
# You should get:
#
# The 5th Fibonacci number is 5
#
# The 10th Fibonacci number is 55
#
# The 15th Fibonacci number is 610

# %% [markdown]
# #### 31 - Calculator with *args
#
# Write a function sum_and_average(*nums) that returns both the sum and the average of the numbers passed in.

# %% [markdown]
# #### 32 - Grade Calculator
#
# Write a function grade(score) that returns "A", "B", "C", "D", or "F" based on the score.

# %% [markdown]
# #### 33 - Anagram Checker
#
# Write a function is_anagram(word1, word2) that checks if two words are anagrams (contain the same letters in any order).

# %% [markdown]
# #### 34 - Prime Number Checker
#
# Write a function is_prime(n) that returns True if n is prime, otherwise False.
#
# Try to get the following output:
#
# Is 3 prime? -> True
#
# Is 10 prime? -> False
#
# Is 13 prime? -> True

# %% [markdown]
# #### 35 - Caesar Cipher
#
# Write a function encrypt(text, shift=3) that shifts each letter forward in the alphabet by the given amount.
#
# Sample output:
#
# encrypt('abc', 2) -> 'cde'
#
# encrypt('cde', -2) -> 'abc'
