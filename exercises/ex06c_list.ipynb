# %% [markdown]
# ### Creating Lists

# %% [markdown]
# #### 1
# Create an empty list called students.

# %% [markdown]
# #### 2
# Use the list() constructor to make a list from the string 'Toronto'.

# %% [markdown]
# #### 3
#
# Create a list using assignment that contains: your name, your age, and your favorite number.

# %% [markdown]
# #### 4
#
# Use range() to make a list of the first 10 even numbers.

# %% [markdown]
# ### append()

# %% [markdown]
# #### 5
# Start with numbers = [1, 2, 3]. Append the number 4.
#
# Append the string 'hello' to the same list. What happens?
#
# Append the list [5, 6]. How many items does the list now have?

# %% [markdown]
# ### extend()

# %% [markdown]
# #### 6
# Start with letters = ['a', 'b']. Extend it with ['c', 'd'].
#
# Extend letters with the string 'ef'. What happens?
#
# Compare the results of using append('ef') and extend('ef').

# %% [markdown]
# ### insert()

# %% [markdown]
# #### 7
# Start with colors = ['red', 'blue', 'green']. Insert 'yellow' at position 1.
#
# Insert 'purple' at a position larger than the listâ€™s length. Where does it go?

# %% [markdown]
# ### pop()

# %% [markdown]
# #### 8
# Create pets = ['cat', 'dog', 'parrot']. Pop the last item.
#
# Pop the first item (index 0).
#
# Try popping from an empty list. What happens?

# %% [markdown]
# ### remove()

# %% [markdown]
# #### 9
# Create fruits = ['apple', 'banana', 'cherry', 'banana']. Remove 'banana'.
#
# What happens if you try to remove 'grape'?

# %% [markdown]
# ### reverse()

# %% [markdown]
# #### 10
# Make a list of numbers 1â€“10. Reverse it using .reverse().
#
# Reverse it again using slicing ([::-1]).

# %% [markdown]
# ### sort()

# %% [markdown]
# #### 11
# Sort the list [3, 1, 4, 1, 5, 9].
#
# Sort the list ['pear', 'apple', 'banana'].
#
# Sort the same list by length of the words (use key=len).

# %% [markdown]
# ### Copy vs Assignment

# %% [markdown]
# #### 12
# Create a list a = [1, 2, 3]. Assign it to b = a.
#
# Append 4 to a. What happens to b?
#
# Create a shallow copy with c = a.copy(). Append 5 to c. Does a change?

# %% [markdown]
# ### Shallow vs Deep Copy

# %% [markdown]
# #### 13
# 1.  Create nested = [[1, 2], [3, 4]].
#
# 1.  Make a shallow copy: copy1 = nested.copy().
#
#     -   Append 99 to the first inner list of copy1.
#
#     -   Print both nested and copy1.
#
# 1.  Repeat with deepcopy from the copy module. Whatâ€™s different?

# %% [markdown]
# #### 14

# %% [markdown]
# #### 15

# %% [markdown]
# #### 16

# %% [markdown]
# #### 17

# %% [markdown]
# #### 18

# %% [markdown]
# #### 19
