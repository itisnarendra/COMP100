# %% [markdown]
# #### 1: File Modes and Attributes
# -   Open a file called `hello.txt` in write mode, write `'Hello, Python!'`, and close it. Then reopen it in read mode and print its contents.
# -   Open the same file and print out:
#     -   the file name
#     -   the mode it was opened in
#     -   whether the file is closed or not

# %% [markdown]
# #### 2: File Writing
# -   Write your 5 most **favorite movie titles** (one per line) into a file called `movies.txt`.
# -   Modify your program to append two more movie titles without erasing the original file.

# %% [markdown]
# #### 3: File Reading
# Write a program that asks the user for a filename and tries to open and read it. If the file doesn't exist, print a friendly error message. Ensure the file object is closed regardless of success or failure.
# Handle exceptions for:
# -   File not found.
# -   Permission errors.
# Respond with clear messages for each error type.

# %% [markdown]
# #### 4: File Reading
# -   Read the contents of movies.txt and print them all at once.
# -   Read movies.txt line by line and print each line with a number (e.g., `1. Inception`).

# %% [markdown]
# #### 5: Binary Files
# -   Write the following list of numbers as bytes to numbers.bin:
# data = [10, 20, 30, 40, 50]
# Then read it back and print the binary contents.
# -   Write the string "Hello, Binary!" to a binary file and then read it back, decoding it as UTF-8.

# %% [markdown]
# #### 5: Character Encodings
#
# -   Write the string `'Bonjour, Ã§a va ?'` into `french.txt` using UTF-8 encoding.
# -   Read the file back using UTF-8 and print it.
# -   Try opening the same file with ASCII encoding and observe what happens.

# %% [markdown]
# #### 6: Working with CSV Files
#
# -   Create a CSV file called students.csv with the following rows:
#
# | Name	| Age	| Grade  |
# |-------|-------|--------|
# | Alice	| 20	| 85  |
# | Bob	| 22	| 72  |
# | Clara	| 19	| 90  |
#
# Write code to read the CSV and print each studentâ€™s name and grade.
#
# -   Write a program that adds a new student (David, 21, 78) to students.csv.
#
# -   Modify the program so that it reads the CSV and prints only the students who scored above 80.

# %% [markdown]
# #### 7: Working with JSON Files
#
# -   Create a dictionary with your personal details (name, age, favorite programming language) and save it to `me.json`.
# -   Read the file back and print the data.
# -   Add a new field `'hobbies': ['reading', 'gaming']` to the dictionary and save the updated file.

# %% [markdown]
# #### 8: File Statistics
# Write a program that reads a text file and displays statistics (number of lines, words, and characters). Handle these exceptions:
#
# File not found
# Permission denied
# Empty file (create a custom exception for this)
#
# Print an appropriate message for each error type.

# %% [markdown]
# #### 9: Configuration File Reader
# Write a program that reads a configuration file in the format:
# username=admin
# password=secret123
# port=8080
# Create custom exceptions:
#
# ConfigFileError (base exception)
# MissingConfigError (file not found)
# InvalidFormatError (line doesn't contain '=')
# MissingKeyError (required key not present)
#
# Parse the file and validate that required keys exist.
