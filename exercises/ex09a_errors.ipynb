# %% [markdown]
# #### 1: Basic try-except
# Write a program that asks the user for two numbers and divides the first by the second. Handle the case where the user enters zero as the second number.

# %% [markdown]
# #### 2: Integer Conversion
# Write a program that repeatedly asks the user to enter an integer. If they enter something that's not a valid integer, catch the error and ask them to try again. Continue until they enter a valid integer.

# %% [markdown]
# #### 3: List Index Safety
# Write a function safe_get(lst, index) that returns the element at the given index if it exists, or returns None if the index is out of range. Use exception handling to implement this.

# %% [markdown]
# #### 4: Dictionary Lookup
# Write a program that stores student grades in a dictionary. Ask the user for a student name and display their grade. Handle the case where the student name doesn't exist in the dictionary.

# %% [markdown]
# #### 5: Multiple Exception Types
# Write a program that prompts the user to enter a password. Raise a `ValueError` if the password is less than 8 characters. Raise a `TypeError` if the password contains any spaces. Use try-except blocks to handle these errors and print appropriate messages.

# %% [markdown]
# #### 6: Multiple Exception Types
# Write a program that tries to convert a userâ€™s input to an integer and then divides 100 by that number.
# -   Catch ValueError if the input is not a number
# -   Catch ZeroDivisionError if the user enters 0

# %% [markdown]
# ### Intermediate Exercises

# %% [markdown]
# #### 7: Age Validator with else and finally
# Write a program that asks for a user's age and validates it. Use:
#
# try to convert the input to an integer
# except to handle invalid input
# else to print a success message
# finally to print "Validation complete"
#
# Also check that the age is between 0 and 120.

# %% [markdown]
# #### 9: Temperature Converter
# Create a temperature converter with exception handling:
#
# Ask the user for a temperature and scale (C or F)
# Convert between Celsius and Fahrenheit
# Handle invalid numeric input
# Handle invalid scale input
# Raise an exception if the temperature is below absolute zero (-273.15Â°C or -459.67Â°F)

# %% [markdown]
# #### 10: Safe Calculator
# Create a calculator program that:
#
# Displays a menu of operations (add, subtract, multiply, divide, modulo)
# Takes two numbers as input
# Performs the operation
# Handles all possible exceptions
# Uses a finally block to ask if the user wants to perform another calculation

# %% [markdown]
# #### 11: Custom Exception - InvalidEmailError
# Create a custom exception called InvalidEmailError and write a function validate_email(email) that:
#
# Checks if the email contains exactly one '@' symbol
# Checks if there's at least one character before and after '@'
# Checks if there's a '.' after the '@'
# Raises InvalidEmailError with a specific message for each violation

# %% [markdown]
# #### 12: Bank Account with Custom Exceptions
# Create a BankAccount class with custom exceptions:
#
# InsufficientFundsError - when withdrawal exceeds balance
# InvalidAmountError - when amount is negative or zero
# AccountFrozenError - when account is frozen

# %% [markdown]
# #### 13: File Processing Pipeline
# Write a program that:
#
# Reads a CSV file with student names and scores
# Calculates the average score
# Writes the results to a new file
#
# Handle these exceptions:
#
# File not found
# Invalid data format (non-numeric scores)
# Empty file
# Write permission errors
#
# Use try-except-else-finally structure appropriately.

# %% [markdown]
# #### 14: Robust User Input
# Create a function get_validated_input(prompt, data_type, min_val=None, max_val=None) that:
#
# Repeatedly asks for user input until valid
# Converts to the specified data type (int, float, str)
# Optionally validates range (min and max)
# Handles all exceptions gracefully
# Returns the validated value

# %% [markdown]
# ####

# %% [markdown]
# ####
